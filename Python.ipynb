# %% [markdown]
# - Matplotlib
# - scatter plot

# %%
world ={
    "afganistan": 30.78,
    "albania": 2.87,
    "algeria": 39.21,
}
for key,value in world.items():
    print(key + "--" + str(value))
# Out:
# afganistan--30.78
# albania--2.87
# algeria--39.21
