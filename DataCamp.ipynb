# %% [markdown]
# <a href="https://colab.research.google.com/github/Julfikar-Asif/Learning_DA_Datacamp/blob/main/DataCamp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.  Matplotlib
# 2. Scatter plot
# 3. Histrogram

# %%
import matplotlib.pyplot as plt
year = [2010,2012, 2014,2016,2018,2020]
popu= [2.5, 2.6, 2.7, 2.8, 2.9, 3.0]
#plt.plot(year,popu)
plt.scatter(year,popu)
plt.xscale("log")
plt.yscale("log")
plt.title("Population Growth")
plt.xlabel("Year")
plt.ylabel("Population")
plt.xticks([1,2,3,4,5])
plt.show()

# %%
import matplotlib.pyplot as plt
year = [2010,2012, 2014,2016,2018,2020]
popu= [2.5, 2.6, 2.7, 2.8, 2.9, 3.0]
#plt.plot(year,popu)
plt.scatter(year,popu)
plt.xscale("log")
plt.yscale("log")
plt.title("Population Growth")
plt.xlabel("Year")
plt.ylabel("Population")
plt.xticks([1,2,3,4,5])
plt.show()

# %%
import matplotlib.pyplot as plt
year = [2010,2012, 2014,2016,2018,2020]
popu= [2.5, 2.6, 2.7, 2.8, 2.9, 3.0]
#plt.plot(year,popu)
plt.scatter(year,popu)
# plt.xscale("log")
# plt.yscale("log")
plt.title("Population Growth")
plt.xlabel("Year")
plt.ylabel("Population")
plt.xticks([1,2,3,4,5,6])
plt.show()

# %%
import matplotlib.pyplot as plt
year = [2010,2012, 2014,2016,2018,2020]
popu= [2.5, 2.6, 2.7, 2.8, 2.9, 3.0]
#plt.plot(year,popu)
plt.scatter(year,popu)
# plt.xscale("log")
# plt.yscale("log")
plt.title("Population Growth")
plt.xlabel("Year")
plt.ylabel("Population")
plt.xticks([2010,2012, 2014,2016,2018,2020],['1','2','3','4','5','6'])
plt.show()

# %%
#help(plt.hist)

value = [0,0.8,0.5,1.2,2.3,2.4,4.2,1.2,3.5,3.4,2.4,3.1]
plt.hist(value , bins=5)
plt.show()

# %% [markdown]
# 1.   Dictonaries

# %%
pop = [30.44, 3.55, 7.33]
coun = ["afganistan", "norway", "ireland"]
# index = coun.index("norway")
# index
world = {"afganistan" : 3.44, "albania": 1.44, "norway": 0.66}
world["norway"]

countries = ['spain', 'france', 'germany', 'norway']
capitals = ['madrid', 'paris', 'berlin', 'oslo']
ind_gr = countries.index("germany")
print(capitals[ind_gr])
# Out:
# berlin

# %%
europe = {'spain':'madrid', 'france':'paris', 'germany':'berlin', 'norway':'oslo' }

# Print out the keys in europe
print(europe.keys())

# Print out value that belongs to key 'norway'
print(europe['norway'])
# Out:
# dict_keys(['spain', 'france', 'germany', 'norway'])
# oslo

# %%
# Definition of dictionary
europe = {'spain':'madrid', 'france':'paris', 'germany':'berlin', 'norway':'oslo' }

# Add italy to europe
europe['italy'] = 'rome'

# Print out italy in europe
print('italy' in europe)

# Add poland to europe
europe['poland'] = 'warsaw'

# Print europe
print(europe)
# Out:
# True
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'italy': 'rome', 'poland': 'warsaw'}

# %%
# Definition of dictionary
europe = {'spain':'madrid', 'france':'paris', 'germany':'bonn',
          'norway':'oslo', 'italy':'rome', 'poland':'warsaw',
          'australia':'vienna' }

# Update capital of germany
europe['germany'] = 'berlin'

# Remove australia
europe.pop('australia')

# Print europe
print(europe)
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'italy': 'rome', 'poland': 'warsaw'}

# %%
# Dictionary of dictionaries
europe = { 'spain': { 'capital':'madrid', 'population':46.77 },
           'france': { 'capital':'paris', 'population':66.03 },
           'germany': { 'capital':'berlin', 'population':80.62 },
           'norway': { 'capital':'oslo', 'population':5.084 } }


# Print out the capital of France
print(europe['france'])

# Create sub-dictionary data
data = { 'capital': 'rome', 'population': 59.83

}

# Add data to europe under key 'italy'
europe['italy'] = data

# Print europe
print(europe)
# Out:
# {'capital': 'paris', 'population': 66.03}
# {'spain': {'capital': 'madrid', 'population': 46.77}, 'france': {'capital': 'paris', 'population': 66.03}, 'germany': {'capital': 'berlin', 'population': 80.62}, 'norway': {'capital': 'oslo', 'population': 5.084}, 'italy': {'capital': 'rome', 'population': 59.83}}

# %% [markdown]
# 1.   **Pandas**
#       * Dataframe from Dictionary
#
#
#
# *   **Square Brackets:**
#
# Single square brackets ([]) return a Pandas Series.
#
# Double square brackets ([[]]) return a Pandas DataFrame.
#
#
# ```
# # cars['country']  # Series
# cars[['country']]  # DataFrame
# ```
#
#
# *   **Selecting Rows with Slicing:**
#
# Use slices to select specific rows.
#
#
# ```
# # cars[0:3]  # First three rows
# ```
#
# *  **loc and iloc:**
#
# loc is label-based, using row and column labels.
#
# iloc is index-based, using integer positions.
#
#
# ```
# # cars.loc['RU']  # Row for Russia using label
# cars.iloc[4]  # Row for Russia using index
# ```
#
#
#
# *  ** Combining Rows and Columns:**
#
# Use loc and iloc to select specific rows and columns simultaneously.
#
# ```
# # `cars.loc[['RU', 'MOR'], ['country', 'drives_right']]  # Specific rows and columns`
# ```

# %%
dict ={
    "Country" : ["Brazil", "Russia", "India", "China", "South Africa"],
    "Capital" : ["Brasilia", "Moscow", " New Delhi", "Beijing", "Pretoria"],
    "Area" : [8.516, 17.10, 3.286, 9.597,1.221],
    "Population" : [200.4, 143.5,1252,1357,52.98]
}

import pandas as pd
brics= pd.DataFrame(dict)
brics
# Out:
#         Country     Capital    Area  Population
# 0        Brazil    Brasilia   8.516      200.40
# 1        Russia      Moscow  17.100      143.50
# 2         India   New Delhi   3.286     1252.00
# 3         China     Beijing   9.597     1357.00
# 4  South Africa    Pretoria   1.221       52.98

# %%
brics=pd.read_csv("/content/brics.csv", index_col= 0)
brics.index = ["BR", "RU", "IN", "CH", "SA"]
brics
# Out:
#          Country    Capital    Area  Population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %% [markdown]
# *   **Pandas**
#       * Row access , col access

# %%
print(brics.loc[:,"Country"])
print(brics.loc[:,['Country','Capital']])
# Out:
# BR          Brazil
# RU          Russia
# IN           India
# CH           China
# SA    South Africa
# Name: Country, dtype: object
#          Country    Capital
# BR        Brazil   Brasilia
# RU        Russia     Moscow
# IN         India  New Delhi
# CH         China    Beijing
# SA  South Africa   Pretoria

# %%
area = 10.0
if(area < 9) :
    print("small")
elif(area < 12) :
    print("medium")
else :
    print("large")
# Out:
# medium

# %%
# Import cars data
import pandas as pd
cars = pd.read_csv('cars.csv', index_col = 0)
# Create car_maniac: observations that have a cars_per_cap over 500
cpc = cars['cars_per_cap']
many_cars = cpc > 500
car_maniac = cars[many_cars]

# Print car_maniac
print(car_maniac)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_946/4118092038.py in <cell line: 0>()
#       1 # Import cars data
#       2 import pandas as pd
# ----> 3 cars = pd.read_csv('cars.csv', index_col = 0)
#       4 # Create car_maniac: observations that have a cars_per_cap over 500
#       5 cpc = cars['cars_per_cap']
#
# ...

# %%
x = 1
while x < 4 :
    print(x)
    x = x + 1


fam = [1.73, 1.68, 1.71, 1.89]
for index, height in enumerate(fam) :
    print("person " + str(index) + ": " + str(height))
# Out:
# 1
# 2
# 3
# person 0: 1.73
# person 1: 1.68
# person 2: 1.71
# person 3: 1.89

# %%
# house list of lists
house = [["hallway", 11.25],
         ["kitchen", 18.0],
         ["living room", 20.0],
         ["bedroom", 10.75],
         ["bathroom", 9.50]]

# Build a for loop from scratch
for room in house :
    print("the " + room[0]+ " is "+ str(room[1]) + " sqm")
# Out:
# the hallway is 11.25 sqm
# the kitchen is 18.0 sqm
# the living room is 20.0 sqm
# the bedroom is 10.75 sqm
# the bathroom is 9.5 sqm

# %% [markdown]
# ### Option 1: Upload your own `cars.csv`
#
# 1.  **Click the folder icon** on the left sidebar in Colab to open the file browser.
# 2.  **Click the upload icon** (looks like an upward arrow) and select your `cars.csv` file from your local machine.
# 3.  Once uploaded, the file will be in the `/content/` directory. You can then use `'cars.csv'` as the path in `pd.read_csv()`.

# %% [markdown]
# ### Option 2: Create a dummy `cars.csv` for testing

# %%
import pandas as pd

# Create dummy data for cars.csv
dummy_cars_data = {
    'country': ['US', 'DE', 'JP', 'IN', 'RU'],
    'cars_per_cap': [800, 543, 630, 20, 200],
    'drives_right': [True, False, False, False, False]
}

dummy_cars_df = pd.DataFrame(dummy_cars_data, index=['US', 'GER', 'JPN', 'IND', 'RUS'])

# Save to cars.csv in the content directory
dummy_cars_df.to_csv('cars.csv')

print("Dummy 'cars.csv' created successfully!")
display(dummy_cars_df.head())
# Out:
# Dummy 'cars.csv' created successfully!
#     country  cars_per_cap  drives_right
# US       US           800          True
# GER      DE           543         False
# JPN      JP           630         False
# IND      IN            20         False
# RUS      RU           200         False

# %%
import pandas as pd
cars = pd.read_csv('cars.csv', index_col = 0)

# Use .apply(str.upper) to create the 'COUNTRY' column
cars['COUNTRY'] = cars['country'].apply(str.upper)
display(cars)
# Out:
#     country  cars_per_cap  drives_right COUNTRY
# US       US           800          True      US
# GER      DE           543         False      DE
# JPN      JP           630         False      JP
# IND      IN            20         False      IN
# RUS      RU           200         False      RU

# %% [markdown]
# *  Hacker statistics to chances to winning a bet.
# *  Use random number generators, loops, and Matplotlib to gain a competitive edge!

# %%
import numpy as np
np.random.seed(123)
outcomes = []
for x in range(10) :
  coin = np.random.randint(0,2)
  if coin == 0 :
    outcomes.append("heads")
  else :
    outcomes.append("tails")
print(outcomes)
# Out:
# ['heads', 'tails', 'heads', 'heads', 'heads', 'heads', 'heads', 'tails', 'tails', 'heads']

# %%
tails = [0]
for x in range(10):
  coin = np.random.randint(0,2)
  tails.append(tails[x]+ coin)
print(tails)
# Out:
# [0, 0, 1, 2, 3, 3, 3, 4, 4, 4, 5]

# %%
# NumPy is imported, seed is set

# Initialize random_walk
random_walk = [0]

# Complete the ___
for x in range(100) :
    # Set step: last element in random_walk
    step = random_walk[-1]

    # Roll the dice
    dice = np.random.randint(1,7)

    # Determine next step
    if dice <= 2:
        step = step - 1
    elif dice <= 5:
        step = step + 1
    else:
        step = step + np.random.randint(1,7)

    # append next_step to random_walk
    random_walk.append(step)

# Print random_walk
print (random_walk)
# Out:
# [0, -1, 0, -1, 0, 1, 2, 3, 2, 6, 7, 6, 7, 6, 7, 8, 9, 10, 11, 12, 13, 16, 17, 18, 19, 24, 25, 29, 30, 29, 30, 31, 30, 31, 32, 34, 35, 36, 35, 34, 35, 36, 35, 34, 35, 36, 38, 37, 36, 37, 36, 37, 38, 39, 41, 40, 41, 42, 43, 44, 45, 44, 43, 44, 43, 44, 45, 44, 47, 48, 49, 50, 49, 50, 51, 55, 54, 53, 55, 54, 55, 57, 58, 59, 64, 63, 64, 65, 66, 67, 68, 67, 72, 73, 74, 75, 74, 73, 72, 71, 70]

# %%
# NumPy is imported, seed is set

# Initialize random_walk
random_walk = [0]

for x in range(100) :
    step = random_walk[-1]
    dice = np.random.randint(1,7)

    if dice <= 2:
        # Replace below: use max to make sure step can't go below 0
        step = max(0,step -1 )
    elif dice <= 5:
        step = step + 1
    else:
        step = step + np.random.randint(1,7)

    random_walk.append(step)

print(random_walk)
# Out:
# [0, 1, 2, 3, 9, 8, 7, 6, 7, 8, 9, 8, 9, 10, 9, 14, 15, 14, 13, 12, 11, 12, 11, 10, 12, 13, 16, 17, 19, 20, 21, 22, 21, 20, 21, 22, 23, 24, 23, 24, 25, 26, 29, 30, 31, 30, 31, 30, 31, 32, 33, 37, 36, 35, 36, 37, 38, 37, 38, 37, 38, 40, 45, 44, 45, 46, 47, 48, 49, 50, 49, 50, 51, 52, 54, 56, 55, 56, 57, 60, 59, 60, 59, 60, 61, 62, 61, 62, 61, 62, 63, 65, 64, 63, 64, 65, 64, 66, 67, 68, 69]

# %%
# NumPy is imported, seed is set

# Initialization
random_walk = [0]

for x in range(100) :
    step = random_walk[-1]
    dice = np.random.randint(1,7)

    if dice <= 2:
        step = max(0, step - 1)
    elif dice <= 5:
        step = step + 1
    else:
        step = step + np.random.randint(1,7)

    random_walk.append(step)

# Import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# Plot random_walk
plt.plot(random_walk)

# Show the plot
plt.show()

# %%
# NumPy is imported; seed is set
import numpy as np
np.random.seed(123)
# Initialize all_walks (don't change this line)
all_walks = []

# Simulate random walk five times
for i in range(5) :

    # Code from before
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)

        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        random_walk.append(step)

    # Append random_walk to all_walks
all_walks.append(random_walk)

# Print all_walks
print(all_walks)
# Out:
# [[0, 6, 5, 6, 5, 4, 5, 9, 10, 11, 12, 13, 12, 11, 10, 9, 8, 9, 10, 11, 12, 13, 14, 13, 14, 15, 14, 15, 16, 19, 18, 19, 18, 19, 22, 23, 24, 25, 24, 23, 26, 27, 28, 29, 28, 27, 28, 31, 32, 37, 38, 37, 38, 37, 38, 37, 43, 42, 41, 42, 44, 43, 42, 41, 42, 43, 44, 45, 49, 54, 55, 56, 57, 60, 61, 62, 63, 64, 65, 66, 65, 64, 65, 66, 65, 71, 70, 71, 72, 71, 70, 71, 70, 69, 75, 74, 73, 74, 75, 74, 73]]

# %%
# numpy and matplotlib imported, seed set.
import matplotlib.pyplot as plt
np.random.seed(123)
# initialize and populate all_walks
all_walks = []
for i in range(5) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        random_walk.append(step)
    all_walks.append(random_walk)

# Convert all_walks to NumPy array: np_aw
np_aw = np.array(all_walks)

# Plot np_aw and show
plt.plot(np_aw)
plt.show()

# Clear the figure
plt.clf()

# Transpose np_aw: np_aw_t
np_aw_t = np.transpose(np_aw)

# Plot np_aw_t and show
plt.plot(np_aw_t)
plt.show()

# %%
# numpy and matplotlib imported, seed set

# clear the plot so it doesn't get cluttered if you run this many times
plt.clf()

# Simulate random walk 20 times
all_walks = []
for i in range(20) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)

        # Implement clumsiness
        if np.random.rand() <= 0.005:
            step = 0

        random_walk.append(step)
    all_walks.append(random_walk)

# Create and plot np_aw_t
np_aw_t = np.transpose(np.array(all_walks))
plt.plot(np_aw_t)
plt.show()

# %%
# numpy and matplotlib imported, seed set

# Simulate random walk 500 times
all_walks = []
for i in range(500) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        if np.random.rand() <= 0.001 :
            step = 0
        random_walk.append(step)
    all_walks.append(random_walk)

# Create and plot np_aw_t
np_aw_t = np.transpose(np.array(all_walks))

# Select last row from np_aw_t: ends
ends = np_aw_t[-1,:]

# Plot histogram of ends, display plot
plt.hist(ends)
plt.show()
np.mean(ends>=60)
# Out:
# np.float64(0.786)

# %%
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]
areas[:6]
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'living room', 20.0]

# %% [markdown]
# *    **Data Manipulation with Pandas**

# %%
import pandas as pd

# Creating a sample homelessness DataFrame based on your description
data = {
    'region': ['East South Central', 'Pacific', 'Mountain', 'West South Central', 'Pacific'],
    'state': ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California'],
    'individuals': [2570.0, 1434.0, 7259.0, 2280.0, 109008.0],
    'family_members': [864.0, 582.0, 2606.0, 432.0, 20964.0],
    'state_pop': [4887681, 735139, 7158024, 3009733, 39461588]
}

homelessness = pd.DataFrame(data)

# 1. Add total_homeless column
homelessness['total_homeless'] = homelessness['individuals'] + homelessness['family_members']

# 2. Add homelessness rate per 10k population
homelessness['homeless_per_10k'] = 10000 * homelessness['total_homeless'] / homelessness['state_pop']

print("Homelessness DataFrame preview:")
display(homelessness.head())
# Out:
# Homelessness DataFrame preview:
#                region       state  individuals  family_members  state_pop  \
# 0  East South Central     Alabama       2570.0           864.0    4887681
# 1             Pacific      Alaska       1434.0           582.0     735139
# 2            Mountain     Arizona       7259.0          2606.0    7158024
# 3  West South Central    Arkansas       2280.0           432.0    3009733
# 4             Pacific  California     109008.0         20964.0   39461588
#
#    total_homeless  homeless_per_10k
# 0          3434.0          7.025827
# 1          2016.0         27.423385
# 2          9865.0         13.781736
# 3          2712.0          9.010766
# 4        129972.0         32.936333

# %%
# Import pandas using the alias pd
import pandas as pd

# Print the values of homelessness
print(homelessness.values)

# Print the column index of homelessness
print(homelessness.columns)
# Print the row index of homelessness
print(homelessness.index)
# Out:
# [['East South Central' 'Alabama' 2570.0 864.0 4887681 3434.0
#   7.025826767336084]
#  ['Pacific' 'Alaska' 1434.0 582.0 735139 2016.0 27.42338523734967]
#  ['Mountain' 'Arizona' 7259.0 2606.0 7158024 9865.0 13.78173641217185]
#  ['West South Central' 'Arkansas' 2280.0 432.0 3009733 2712.0
#   9.01076607127609]
#  ['Pacific' 'California' 109008.0 20964.0 39461588 129972.0
#   32.9363329220304]]
# Index(['region', 'state', 'individuals', 'family_members', 'state_pop',
#        'total_homeless', 'homeless_per_10k'],
#       dtype='object')
# RangeIndex(start=0, stop=5, step=1)

# %%
display(homelessness)
# Out:
#                region       state  individuals  family_members  state_pop  \
# 0  East South Central     Alabama       2570.0           864.0    4887681
# 1             Pacific      Alaska       1434.0           582.0     735139
# 2            Mountain     Arizona       7259.0          2606.0    7158024
# 3  West South Central    Arkansas       2280.0           432.0    3009733
# 4             Pacific  California     109008.0         20964.0   39461588
#
#    total_homeless  homeless_per_10k
# 0          3434.0          7.025827
# 1          2016.0         27.423385
# 2          9865.0         13.781736
# 3          2712.0          9.010766
# 4        129972.0         32.936333

# %%
homelessness[["region","state"]]
homelessness["total_homeless"]>3000
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# Name: total_homeless, dtype: bool

# %%
homelessness.sort_values(["region","state"], ascending=[True,False])
# Out:
#                region       state  individuals  family_members  state_pop  \
# 0  East South Central     Alabama       2570.0           864.0    4887681
# 2            Mountain     Arizona       7259.0          2606.0    7158024
# 4             Pacific  California     109008.0         20964.0   39461588
# 1             Pacific      Alaska       1434.0           582.0     735139
# 3  West South Central    Arkansas       2280.0           432.0    3009733
#
#    total_homeless  homeless_per_10k
# 0          3434.0          7.025827
# 2          9865.0         13.781736
# 4        129972.0         32.936333
# 1          2016.0         27.423385
# 3          2712.0          9.010766

# %%
# Sort homelessness by region, then descending family members
homelessness_reg_fam = homelessness.sort_values(["region","family_members"], ascending =[True,False])

# Print the top few rows
print(homelessness_reg_fam.head())
# Out:
#                region       state  individuals  family_members  state_pop  \
# 0  East South Central     Alabama       2570.0           864.0    4887681
# 2            Mountain     Arizona       7259.0          2606.0    7158024
# 4             Pacific  California     109008.0         20964.0   39461588
# 1             Pacific      Alaska       1434.0           582.0     735139
# 3  West South Central    Arkansas       2280.0           432.0    3009733
#
#    total_homeless  homeless_per_10k
# 0          3434.0          7.025827
# 2          9865.0         13.781736
# 4        129972.0         32.936333
# 1          2016.0         27.423385
# 3          2712.0          9.010766

# %%
# Select the state and family_members columns
state_fam = homelessness[["state","family_members"]]

print(state_fam.head())
# Out:
#         state  family_members
# 0     Alabama           864.0
# 1      Alaska           582.0
# 2     Arizona          2606.0
# 3    Arkansas           432.0
# 4  California         20964.0

# %%
# Filter for rows where individuals is greater than 10000
ind_gt_10k = homelessness[homelessness["individuals"]> 10000]
print(ind_gt_10k)
# Out:
#     region       state  individuals  family_members  state_pop  \
# 4  Pacific  California     109008.0         20964.0   39461588
#
#    total_homeless  homeless_per_10k
# 4        129972.0         32.936333

# %%
# Filter for rows where family_members is less than 1000
# and region is Pacific
fam_lt_1k_pac = homelessness[(homelessness["family_members"]<1000) & (homelessness["region"] == "Pacific")]

# See the result
print(fam_lt_1k_pac)
# Out:
#     region   state  individuals  family_members  state_pop  total_homeless  \
# 1  Pacific  Alaska       1434.0           582.0     735139          2016.0
#
#    homeless_per_10k
# 1         27.423385

# %%
# The Mojave Desert states
canu = ["California", "Arizona", "Nevada", "Utah"]

# Filter for rows in the Mojave Desert states
mojave_homelessness = homelessness[homelessness["state"].isin(canu)]

# See the result
print(mojave_homelessness)
# Out:
#      region       state  individuals  family_members  state_pop  \
# 2  Mountain     Arizona       7259.0          2606.0    7158024
# 4   Pacific  California     109008.0         20964.0   39461588
#
#    total_homeless  homeless_per_10k
# 2          9865.0         13.781736
# 4        129972.0         32.936333

# %%
# Add total col as sum of individuals and family_members
homelessness["total"] = homelessness["individuals"] + homelessness["family_members"]
# Add p_homeless col as proportion of total homeless population to the state population
homelessness["p_homeless"] = homelessness["total"] / homelessness["state_pop"]
# See the result
print(homelessness)
# Out:
#                region       state  individuals  family_members  state_pop  \
# 0  East South Central     Alabama       2570.0           864.0    4887681
# 1             Pacific      Alaska       1434.0           582.0     735139
# 2            Mountain     Arizona       7259.0          2606.0    7158024
# 3  West South Central    Arkansas       2280.0           432.0    3009733
# 4             Pacific  California     109008.0         20964.0   39461588
#
#    total_homeless  homeless_per_10k     total  p_homeless
# 0          3434.0          7.025827    3434.0    0.000703
# 1          2016.0         27.423385    2016.0    0.002742
# 2          9865.0         13.781736    9865.0    0.001378
# 3          2712.0          9.010766    2712.0    0.000901
# 4        129972.0         32.936333  129972.0    0.003294

# %%
# Create indiv_per_10k col as homeless individuals per 10k state pop
homelessness["indiv_per_10k"] = 10000 * homelessness["individuals"] / homelessness["state_pop"]



# Subset rows for indiv_per_10k greater than 20
high_homelessness = homelessness[homelessness["indiv_per_10k"]>20]

# Sort high_homelessness by descending indiv_per_10k
high_homelessness_srt = high_homelessness.sort_values("indiv_per_10k", ascending=False)

# From high_homelessness_srt, select the state and indiv_per_10k cols
result = high_homelessness_srt[["state","indiv_per_10k"]]

# See the result
print(result)
# Out:
#         state  indiv_per_10k
# 4  California      27.623825
